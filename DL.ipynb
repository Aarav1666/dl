png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (678).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (187).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (637).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (63).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (517).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (504).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (244).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (157).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (954).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (786).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (473).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (490).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (346).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (11).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (190).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (417).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (256).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (362).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (499).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (933).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (858).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (665).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (623).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (686).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (613).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (502).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (383).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (989).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (805).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (35).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (776).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (51).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (184).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (690).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (496).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (908).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (973).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (691).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (541).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (973).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (723).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (263).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (745).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (351).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (115).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (931).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (405).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (117).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (945).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (894).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (687).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (40).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (220).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (634).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (619).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (667).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (769).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (445).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (283).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (368).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (597).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (621).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (100).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (553).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (458).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (114).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (324).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (498).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (475).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (814).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (657).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (696).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (580).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (602).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (155).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (594).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (211).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (282).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (701).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (595).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (66).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (666).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (223).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (273).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (751).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (289).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (147).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (429).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (411).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (382).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (62).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (534).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (393).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (268).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (969).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (408).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (27).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (929).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (19).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (840).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (537).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (570).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (874).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (937).png',
#  'C:\\Users\\radha\\DLProject\\data2\\dog (138).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (784).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (227).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (539).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (251).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (602).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (629).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (259).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (429).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (365).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (700).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (640).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (590).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (292).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (570).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (250).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (116).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (295).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (586).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (670).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (653).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (546).png',
#  'C:\\Users\\radha\\DLProject\\data2\\ship (604).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (234).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (920).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (794).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (461).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (897).png',
#  'C:\\Users\\radha\\DLProject\\data2\\cat (190).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (145).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (968).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (11).png',
#  'C:\\Users\\radha\\DLProject\\data2\\truck (244).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (15).png',
#  'C:\\Users\\radha\\DLProject\\data2\\frog (505).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (410).png',
#  'C:\\Users\\radha\\DLProject\\data2\\horse (428).png',
#  'C:\\Users\\radha\\DLProject\\data2\\aeroplane (458).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (840).png',
#  'C:\\Users\\radha\\DLProject\\data2\\bird (129).png',
#  'C:\\Users\\radha\\DLProject\\data2\\automobile (330).png',
#  'C:\\Users\\radha\\DLProject\\data2\\deer (224).png',
#  ...]

# %%
BATCH_SIZE=200
LATENT_DIM=512
IMAGE_SIZE=64

# %%
# load the training image paths into tensors, create batches and shuffle
training_dataset = tf.data.Dataset.from_tensor_slices((train_paths))
training_dataset = training_dataset.map(map_image)
training_dataset = training_dataset.shuffle(1000).batch(BATCH_SIZE)

validation_dataset = tf.data.Dataset.from_tensor_slices((val_paths))
validation_dataset = validation_dataset.map(map_image)
validation_dataset = validation_dataset.batch(BATCH_SIZE)

# %%
print(f'number of batches in the training set: {len(training_dataset)}')
print(f'number of batches in the validation set: {len(validation_dataset)}')
# Out:
# number of batches in the training set: 40
# number of batches in the validation set: 10

# %%
def display_faces(dataset, size=9):
  '''Takes a sample from a dataset batch and plots it in a grid.'''
  dataset = dataset.unbatch().take(size)
  n_cols = 3
  n_rows = size//n_cols + 1
  plt.figure(figsize=(5, 5))
  i = 0
  for image in dataset:
    i += 1
    disp_img = np.reshape(image, (64,64,3))
    plt.subplot(n_rows, n_cols, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(disp_img)


def display_one_row(disp_images, offset, shape=(28, 28)):
  '''Displays a row of images.'''
  for idx, image in enumerate(disp_images):
    plt.subplot(3, 10, offset + idx + 1)
    plt.xticks([])
    plt.yticks([])
    image = np.reshape(image, shape)
    plt.imshow(image)


def display_results(disp_input_images, disp_predicted):
  '''Displays input and predicted images.'''
  plt.figure(figsize=(15, 5))
  display_one_row(disp_input_images, 0, shape=(IMAGE_SIZE,IMAGE_SIZE,3))
  display_one_row(disp_predicted, 20, shape=(IMAGE_SIZE,IMAGE_SIZE,3))

# %%
display_faces(validation_dataset, size=12)

# %%
class Sampling(tf.keras.layers.Layer):
  def call(self, inputs):
    """Generates a random sample and combines with the encoder output
    
    Args:
      inputs -- output tensor from the encoder

    Returns:
      `inputs` tensors combined with a random sample
    """
    ### START CODE HERE ###
    mu, sigma = inputs
    batch = tf.shape(mu)[0]
    dim = tf.shape(mu)[1]
    epsilon = tf.keras.backend.random_normal(shape = (batch, dim))
    z = mu + tf.exp(0.5 * sigma) * epsilon
    ### END CODE HERE ###
    return  z

# %%
def encoder_layers(inputs, latent_dim):
  """Defines the encoder's layers.
  Args:
    inputs -- batch from the dataset
    latent_dim -- dimensionality of the latent space

  Returns:
    mu -- learned mean
    sigma -- learned standard deviation
    batch_3.shape -- shape of the features before flattening
  """
  ### START CODE HERE ###
  x = tf.keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides = 2, 
                             activation = 'relu', padding = 'same', 
                             name = 'enc_conv1')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Conv2D(filters = 64, kernel_size = (3, 3), strides = 2, 
                             activation = 'relu', padding = 'same', 
                             name = 'enc_conv2')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Conv2D(filters = 128, kernel_size = (3, 3), strides = 2, 
                             activation = 'relu', padding = 'same', 
                             name = 'enc_conv3')(x)
  batch_3 = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Flatten(name = 'enc_flatten')(batch_3)

  x = tf.keras.layers.Dense(1024, activation = 'relu', name = 'enc_dense')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  mu = tf.keras.layers.Dense(LATENT_DIM, name = 'latent_mu')(x)
  sigma = tf.keras.layers.Dense(LATENT_DIM, name = 'latent_sigma')(x)  
  ### END CODE HERE ###

  # revise `batch_3.shape` here if you opted not to use 3 Conv2D layers
  return mu, sigma, batch_3.shape

# %%
def encoder_model(latent_dim, input_shape):
  """Defines the encoder model with the Sampling layer
  Args:
    latent_dim -- dimensionality of the latent space
    input_shape -- shape of the dataset batch

  Returns:
    model -- the encoder model
    conv_shape -- shape of the features before flattening
  """
  ### START CODE HERE ###
  inputs = tf.keras.layers.Input(shape = input_shape)
  mu, sigma, conv_shape = encoder_layers(inputs, latent_dim = LATENT_DIM)
  z = Sampling()((mu, sigma))
  model = tf.keras.Model(inputs, outputs = [mu, sigma, z])
  ### END CODE HERE ###
  model.summary()
  return model, conv_shape

# %%
def decoder_layers(inputs, conv_shape):
  """Defines the decoder layers.
  Args:
    inputs -- output of the encoder 
    conv_shape -- shape of the features before flattening

  Returns:
    tensor containing the decoded output
  """
  ### START CODE HERE ###
  units = conv_shape[1] * conv_shape[2] * conv_shape[3]
  x = tf.keras.layers.Dense(units, activation = 'relu', name = 'dec_dense')(inputs)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Reshape((conv_shape[1], conv_shape[2], conv_shape[3]),
                              name = 'dec_reshape')(x)
  
  x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (3, 3), 
                                      strides = 2, activation = 'relu', 
                                      padding = 'same', name = 'dec_deconv1')(x)
  x = tf.keras.layers.BatchNormalization()(x)

  x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (3, 3), 
                                      strides = 2, activation = 'relu', 
                                      padding = 'same', name = 'dec_deconv2')(x)
  x = tf.keras.layers.BatchNormalization()(x)      

  x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (3, 3), 
                                      strides = 2, activation = 'relu', 
                                      padding = 'same', name = 'dec_deconv3')(x)
  x = tf.keras.layers.BatchNormalization()(x)        

  x = tf.keras.layers.Conv2DTranspose(filters = 3, kernel_size = (3, 3), 
                                      strides = 1, activation = 'sigmoid', 
                                      padding = 'same', name = 'dec_deconv4')(x)
  ### END CODE HERE ###
  return x

# %%
def decoder_model(latent_dim, conv_shape):
  """Defines the decoder model.
  Args:
    latent_dim -- dimensionality of the latent space
    conv_shape -- shape of the features before flattening

  Returns:
    model -- the decoder model
  """
  ### START CODE HERE ###
  inputs = tf.keras.layers.Input(shape = (latent_dim, ))
  outputs = decoder_layers(inputs, conv_shape)
  model = tf.keras.Model(inputs, outputs)
  ### END CODE HERE ###
  model.summary()
  return model

# %%
def kl_reconstruction_loss(inputs, outputs, mu, sigma):
  """ Computes the Kullback-Leibler Divergence (KLD)
  Args:
    inputs -- batch from the dataset
    outputs -- output of the Sampling layer
    mu -- mean
    sigma -- standard deviation

  Returns:
    KLD loss
  """
  kl_loss = 1 + sigma - tf.square(mu) - tf.math.exp(sigma)
  return tf.reduce_mean(kl_loss) * -0.5

# %%
def vae_model(encoder, decoder, input_shape):
  """Defines the VAE model
  Args:
    encoder -- the encoder model
    decoder -- the decoder model
    input_shape -- shape of the dataset batch

  Returns:
    the complete VAE model
  """
  ### START CODE HERE ###
  inputs = tf.keras.layers.Input(shape = input_shape)
  mu, sigma, z = encoder(inputs)
  reconstructed = decoder(z)

  model = tf.keras.Model(inputs, reconstructed)

  loss = kl_reconstruction_loss(inputs, z, mu, sigma)
  model.add_loss(loss)
  ### END CODE HERE ###
  return model

# %%
def get_models(input_shape, latent_dim):
  """Returns the encoder, decoder, and vae models"""
  ### START CODE HERE ###
  encoder, conv_shape = encoder_model(latent_dim = latent_dim, input_shape = input_shape)
  decoder = decoder_model(latent_dim = latent_dim, conv_shape = conv_shape)
  vae = vae_model(encoder, decoder, input_shape = input_shape)
  ### END CODE HERE ###
  return encoder, decoder, vae

# %%
encoder, decoder, vae = get_models(input_shape=(64,64,3,), latent_dim=LATENT_DIM)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  enc_conv1 (Conv2D)             (None, 32, 32, 32)   896         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 32, 32, 32)  128         ['enc_conv1[0][0]']
#  alization)
#
#  enc_conv2 (Conv2D)             (None, 16, 16, 64)   18496       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['enc_conv2[0][0]']
#  rmalization)
#
#  enc_conv3 (Conv2D)             (None, 8, 8, 128)    73856       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 128)   512         ['enc_conv3[0][0]']
#  rmalization)
#
#  enc_flatten (Flatten)          (None, 8192)         0           ['batch_normalization_2[0][0]']
#
#  enc_dense (Dense)              (None, 1024)         8389632     ['enc_flatten[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1024)        4096        ['enc_dense[0][0]']
#  rmalization)
#
#  latent_mu (Dense)              (None, 512)          524800      ['batch_normalization_3[0][0]']
#
#  latent_sigma (Dense)           (None, 512)          524800      ['batch_normalization_3[0][0]']
#
#  sampling (Sampling)            (None, 512)          0           ['latent_mu[0][0]',
#                                                                   'latent_sigma[0][0]']
#
# ==================================================================================================
# Total params: 9,537,472
# Trainable params: 9,534,976
# Non-trainable params: 2,496
# __________________________________________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 512)]             0
#
#  dec_dense (Dense)           (None, 8192)              4202496
#
#  batch_normalization_4 (Batc  (None, 8192)             32768
#  hNormalization)
#
#  dec_reshape (Reshape)       (None, 8, 8, 128)         0
#
#  dec_deconv1 (Conv2DTranspos  (None, 16, 16, 128)      147584
#  e)
#
#  batch_normalization_5 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  dec_deconv2 (Conv2DTranspos  (None, 32, 32, 64)       73792
#  e)
#
#  batch_normalization_6 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  dec_deconv3 (Conv2DTranspos  (None, 64, 64, 32)       18464
#  e)
#
#  batch_normalization_7 (Batc  (None, 64, 64, 32)       128
#  hNormalization)
#
#  dec_deconv4 (Conv2DTranspos  (None, 64, 64, 3)        867
#  e)
#
# =================================================================
# Total params: 4,476,867
# Trainable params: 4,460,035
# Non-trainable params: 16,832
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
loss_metric = tf.keras.metrics.Mean()
mse_loss = tf.keras.losses.MeanSquaredError()
bce_loss = tf.keras.losses.BinaryCrossentropy()

# %%
def generate_and_save_images(model, epoch, step, test_input):
  """Helper function to plot our 16 images

  Args:

  model -- the decoder model
  epoch -- current epoch number during training
  step -- current step number during training
  test_input -- random tensor with shape (16, LATENT_DIM)
  """
  predictions = model.predict(test_input)

  fig = plt.figure(figsize=(4,4))

  for i in range(predictions.shape[0]):
      plt.subplot(4, 4, i+1)
      img = predictions[i, :, :, :] * 255
      img = img.astype('int32')
      plt.imshow(img)
      plt.axis('off')

  # tight_layout minimizes the overlap between 2 sub-plots
  fig.suptitle("epoch: {}, step: {}".format(epoch, step))
  plt.savefig('image_at_epoch_{:04d}_step{:04d}.png'.format(epoch, step))
  plt.show()

# %%
# Training loop. Display generated images each epoch

### START CODE HERE ###
epochs = 100
### END CODE HERE ###

random_vector_for_generation = tf.random.normal(shape=[16, LATENT_DIM])
generate_and_save_images(decoder, 0, 0, random_vector_for_generation)

for epoch in range(epochs):
  print('Start of epoch %d' % (epoch,))

  # Iterate over the batches of the dataset.
  for step, x_batch_train in enumerate(training_dataset):
    with tf.GradientTape() as tape:
      ### START CODE HERE ### 
      reconstructed = vae(x_batch_train)
      # Compute reconstruction loss
      flattened_inputs = tf.reshape(x_batch_train, shape = [-1])
      flattened_outputs = tf.reshape(reconstructed, shape = [-1])
      loss = mse_loss(flattened_inputs, flattened_outputs) * 64 * 64 * 3
      loss += sum(vae.losses)
    grads = tape.gradient(loss, vae.trainable_weights)
    optimizer.apply_gradients(zip(grads, vae.trainable_weights))
    ### END CODE HERE
    
    loss_metric(loss)

    if step % 10 == 0:
      display.clear_output(wait=False)    
      generate_and_save_images(decoder, epoch, step, random_vector_for_generation)
    print('Epoch: %s step: %s mean loss = %s' % (epoch, step, loss_metric.result().numpy()))
# Out:
# Epoch: 99 step: 30 mean loss = 36.26437
# Epoch: 99 step: 31 mean loss = 36.261482
# Epoch: 99 step: 32 mean loss = 36.258587
# Epoch: 99 step: 33 mean loss = 36.25564
# Epoch: 99 step: 34 mean loss = 36.252666
# Epoch: 99 step: 35 mean loss = 36.24974
# Epoch: 99 step: 36 mean loss = 36.24679
# Epoch: 99 step: 37 mean loss = 36.243767
# Epoch: 99 step: 38 mean loss = 36.240803
# Epoch: 99 step: 39 mean loss = 36.237843

# %%
pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in d:\anaconda\lib\site-packages (4.5.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: dill in d:\anaconda\lib\site-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (3.19.1)
#
# Requirement already satisfied: promise in d:\anaconda\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: termcolor in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: six in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (1.16.0)
# Requirement already satisfied: numpy in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (1.22.0)
# Requirement already satisfied: absl-py in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (1.0.0)
# Requirement already satisfied: tensorflow-metadata in d:\anaconda\lib\site-packages (from tensorflow_datasets) (1.7.0)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from tensorflow_datasets) (4.62.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\radha\appdata\roaming\python\python39\site-packages (from tensorflow_datasets) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\radha\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\radha\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->tensorflow_datasets) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\radha\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\radha\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.10)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in d:\anaconda\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.56.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->tensorflow_datasets) (0.4.4)

# %%
test_dataset = validation_dataset.take(1)
output_samples = []

for input_image in tfds.as_numpy(test_dataset):
      output_samples = input_image

idxs = np.random.choice(64, size=10)

vae_predicted = vae.predict(test_dataset)
display_results(output_samples[idxs], vae_predicted[idxs])

# %%
import tensorflow_datasets as tfds

# %%
def plot_images(rows, cols, images, title):
    '''Displays images in a grid.'''
    grid = np.zeros(shape=(rows*64, cols*64, 3))
    for row in range(rows):
        for col in range(cols):
            grid[row*64:(row+1)*64, col*64:(col+1)*64, :] = images[row*cols + col]

    plt.figure(figsize=(12,12))       
    plt.imsave("savedimg.jpg", grid)
    plt.title(title)
    plt.show()

# initialize random inputs
test_vector_for_generation = tf.random.normal(shape=[64, LATENT_DIM])

# get predictions from the decoder model
predictions= decoder.predict(test_vector_for_generation)

# plot the predictions
plot_images(8,8,predictions,'Generated Images')
